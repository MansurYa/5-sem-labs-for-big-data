# %% [markdown]
# ### Задание 2

# %%
import pandas as pd

df = pd.read_parquet('washing.parquet')

print(f"{df.shape[0]} строк, {df.shape[1]} колонок")

print(df.columns.tolist())

print(df.dtypes)

print(df.head(10))

print(df.describe())
# Out:
# 2058 строк, 11 колонок
# ['_id', '_rev', 'count', 'flowrate', 'fluidlevel', 'frequency', 'hardness', 'speed', 'temperature', 'ts', 'voltage']
# _id             object
# _rev            object
# count            int64
# flowrate       float64
# fluidlevel      object
# frequency      float64
# hardness       float64
# speed          float64
# temperature    float64
# ts               int64
# voltage        float64
# dtype: object
#                                 _id                                _rev  \
# 0  0d86485d0f88d1f9d60bd193a4306793  1-57940679fb8a713bc46a033b3c495cbe
# 1  0d86485d0f88d1f9d60bd193a4306ee1  1-15ff3a0b304d789e16a71f4b3e540920
# 2  0d86485d0f88d1f9d60bd193a4307322  1-97c2742b68c7b07c2091d817e839f693
# 3  0d86485d0f88d1f9d60bd193a43080fc  1-eefb903dbe4574667b7410be306cf741
# 4  0d86485d0f88d1f9d60bd193a4308701  1-5f68b4c72813c25e12d91004ddb33b1b
# 5  0d86485d0f88d1f9d60bd193a4309533  1-cd4b6c57ddbe77ec72e568a0e863908b
# ...

# %%
try:
    from pyspark import SparkContext, SparkConf
    from pyspark.sql import SparkSession
except ImportError as e:
    printmd('<<<<<!!!!! Please restart your kernel after installing Apache Spark !!!!!>>>>>')

# %%
sc = SparkContext.getOrCreate(SparkConf().setMaster("local[*]"))

spark = SparkSession \
    .builder \
    .getOrCreate()

# %% [markdown]
# # Реализуйте функцию, возвращающую количество строк в dataframe
# def count():
#     # TODO Введите ваш код здесь, вы не обязаны использовать шаблон ниже
#     # справочная информация: https://spark.apache.org/docs/latest/api/python/pyspark.sql.html#pyspark.sql.DataFrame
#     # дополнительная помощь: https://www.w3schools.com/sql/sql_count_avg_sum.asp
#     return spark.sql('''
#         SELECT COUNT(*) AS cnt
#         FROM washing
#     ''').first().cnt

# %%
# Реализуйте функцию, возвращающую количество строк в dataframe
def count():
    # TODO Введите ваш код здесь, вы не обязаны использовать шаблон ниже
    # справочная информация: https://spark.apache.org/docs/latest/api/python/pyspark.sql.html#pyspark.sql.DataFrame
    # дополнительная помощь: https://www.w3schools.com/sql/sql_count_avg_sum.asp
    return spark.sql('''
        SELECT COUNT(*) as cnt 
        FROM washing
    ''').first().cnt

# %% [markdown]
# Теперь пришло время реализовать вторую функцию. Верните целое число, содержащее количество полей (столбцов). Самый простой способ получить это - использовать dataframe API. Подсказка: документация dataframe API может быть полезна: http://spark.apache.org/docs/latest/api/python/pyspark.sql.html#pyspark.sql.DataFrame

# %%
def getNumberOfFields():
    # TODO Введите ваш код здесь, вы не обязаны использовать шаблон ниже
    # справочная информация: https://spark.apache.org/docs/latest/api/python/pyspark.sql.html#pyspark.sql.DataFrame
    return len(df.columns)

# %% [markdown]
# Наконец, реализуйте функцию, которая возвращает (python) список строковых значений имен полей в этом data frame. Подсказка: простое копирование не сработает, потому что автопроверка создаст случайный data frame для тестирования, поэтому используйте data frame API. Опять же, вот ссылка на документацию: http://spark.apache.org/docs/latest/api/python/pyspark.sql.html#pyspark.sql.DataFrame

# %%
def getFieldNames():
    # TODO Введите ваш код здесь, вы не обязаны использовать шаблон ниже
    # справочная информация: https://spark.apache.org/docs/latest/api/python/pyspark.sql.html#pyspark.sql.DataFrame
    return df.columns

# %% [markdown]
# Теперь пришло время взять файл PARQUET и создать из него dataframe. Используя SparkSQL, вы можете обращаться с ним как с базой данных.

# %%
df = spark.read.parquet('washing.parquet')
df.createOrReplaceTempView('washing')
df.show()
# Out:
# +--------------------+--------------------+-----+--------+----------+---------+--------+-----+-----------+-------------+-------+
# |                 _id|                _rev|count|flowrate|fluidlevel|frequency|hardness|speed|temperature|           ts|voltage|
# +--------------------+--------------------+-----+--------+----------+---------+--------+-----+-----------+-------------+-------+
# |0d86485d0f88d1f9d...|1-57940679fb8a713...|    4|      11|acceptable|     NULL|      77| NULL|        100|1547808723923|   NULL|
# |0d86485d0f88d1f9d...|1-15ff3a0b304d789...|    2|    NULL|      NULL|     NULL|    NULL| 1046|       NULL|1547808729917|   NULL|
# |0d86485d0f88d1f9d...|1-97c2742b68c7b07...|    4|    NULL|      NULL|       71|    NULL| NULL|       NULL|1547808731918|    236|
# |0d86485d0f88d1f9d...|1-eefb903dbe45746...|   19|      11|acceptable|     NULL|      75| NULL|         86|1547808738999|   NULL|
# ...

# %% [markdown]
# Следующая ячейка может быть использована для тестирования вашей функции count

# %%
cnt = None
nof = None
fn = None

cnt = count()
print(cnt)
# Out:
# 2058

# %% [markdown]
# Следующая ячейка может быть использована для тестирования вашей функции getNumberOfFields

# %%
nof = getNumberOfFields()
print(nof)
# Out:
# 11

# %% [markdown]
# Следующая ячейка может быть использована для тестирования вашей функции getFieldNames

# %%
fn = getFieldNames()
print(fn)
# Out:
# ['_id', '_rev', 'count', 'flowrate', 'fluidlevel', 'frequency', 'hardness', 'speed', 'temperature', 'ts', 'voltage']

# %% [markdown]
# Поздравляем, вы закончили. Теперь отправьте ваши решения.
